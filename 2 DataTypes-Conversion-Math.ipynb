# %%
text1 = 'strings are important'
print(text1)  # text1 is a variable now. If we print this variable, we get the value stored at it.
# If I use print('text1') (in single quotes) then I get texxt 1 as output.
# Out:
# strings are important

# %%
# lowercase 'l', uppercase 'I', sayı 1 veya uppercase 'O' variable ismi olmamalı tek basina. 
# or, if, else vs keywordler oldugu icin tek basina variable name olarak kullanılamaz.
# variable isminde ünlem, bosluk, orta tire, rakamla baslama (2me), dolar isareti gibi ozel karakterle baslama olmaz
# _al?i = 'absurd'  # calismaz bu error verir  
# bu arada print yazmadan da calistiriyor!
# bir degiskene o an deger atamak istemiyorsak None yazariz. Walter dursun ama diger variablelarla gorunmesin. yeri rezerve olur.
# python yukaridan asagi ve soldan saga okur. yani son atanan variable ve degeri
a = 1
b = 2
c = 3

a = 5  # artik a 1 degil 5 yani

# %%
x = 15
y = 33
z = x
x = y
print(x, y, z)
# Out:
# 33 33 15

# %%
a, b, c = 5, 3.2, 'Hello'
print(a, b, c)
# Out:
# 5 3.2 Hello

# %%
type('aliveli') # data type bulmak icin type fonksiyonu 
type('ali, veli, deli')
# Out:
# str

# %%
type(a)  # yukarıda en son a 5
# Out:
# int

# %%
str_no = '1923'
str_sign = '%&//('
print(str_no)
print(str_sign)
print(type(str_no), type(str_sign))
# Out:
# 1923
# %&//(
# <class 'str'> <class 'str'>

# %%
10 == 10.0            # == eşit midir sorusunun cevabı. Bool : True veya False olur cevap
# Out:
# True

# %%
x = y = z = 'same'
print(x)
print(y)
print(z)
print(x, y, z)
print(x + y + z)
# Out:
# same
# same
# same
# same same same
# samesamesame

# %%
text = 'I am string type' #eger bunu quotes olmadan yazarsak error verir
print(text)
print(type(text))  # print(type) komutuyla text'in data typeini bulabiliriz. asagida diger data cesitleri icin ornekler var.
print()
my_age = 41  # sadece numara oldugunda ise yazıyor print deyince - integer number. It's called int.
print(my_age)
print(type(my_age))
print()
my_weight = 74.50  # float point number (with decimal point). It's called float.
print(my_weight)
print(type(my_weight))
print()
a_complex_no = 3+5j  # This is a complex number. It's called complex and has a real number (3) and an imaginary number (5j) 
print(a_complex_no)
print(type(a_complex_no))
print()
your_age = '45'  # These both give the same output. However, trick here is the 1st one is str and the sec is int. 
his_age = 45  # we can also see this by checking their types below. 
print(your_age)
print(his_age)
print(type(your_age))
print(type(his_age))
# Out:
# I am string type
# <class 'str'>
#
# 41
# <class 'int'>
#
# 74.5
# <class 'float'>
#
# (3+5j)
# <class 'complex'>
#
# 45
# 45
# <class 'str'>
# <class 'int'>

# %%
tv_open = True # boolean type. Boolean types are called bool and their values are the two constant objects False and True. 
# They are used to represent truth values (other values can also be considered false or true)
print(type(tv_open))  # Note that we write the first letter of True in uppercase. 
# This is the rule of Python that we must write like this : True, False.

15 == 20-5  # ÇAlıştırınca aşağıda True veya False cevabı verir.
# Out:
# <class 'bool'>
# True

# %%
"30" * 3  # çarpı 3 dersek 3 tane yanyana yazar. ama + veya - olmaz error verir.
# Out:
# '303030'

# %% [markdown]
# **Type** **Conversion**

# %% [markdown]
# commente convert CMD+K+C  uncommend CMD+K+U

# %%
# str() converts to str type
# int() converts to int type
# float converts to float type

f = 7.50  # float type. let's convert it to str
s = str(f)
print(type(s))  # we assigned f value to the s variable and converted it to string.
print(s)  # s is now f, that means 7.50
#some other examples below
print()

integ = 5  # we'll convert int to float in this case.
flo = float(integ)
print(type(flo))
print(flo)
print()
# now let's convert from float to int. 
# while converting a float value to an integer its decimal part is disregarded. 
f_val = 12.80
int_val = int(f_val)
print(type(int_val))
print(int_val)
# Out:
# <class 'str'>
# 7.5
#
# <class 'float'>
# 5.0
#
# <class 'int'>
# 12

# %%
pi = 3.14
converted_pi = str(pi)  # str() converts to string. parantez ici bir fonksiyon demek. parantezin icini str yapar
print(converted_pi)
print(type(converted_pi))
# Out:
# 3.14
# <class 'str'>

# %%
 int("10")  # icindeki str ifadeyi 10 int.a cevirdi
# Out:
# 10

# %%
float('10')
# Out:
# 10.0

# %%
"clarus" + "way"  # + işareti yanyana getirir. "33" + "11" olsa 3311 yazar.
# Out:
# 'clarusway'

# %%
part1 = "clarus"
part2 = "way"
part1 + part2  # + ile variables da toplanabilir. ama aynı type olmalı. burda str mesela. 33 ve 11 olsa burda 44 olur.
# Out:
# 'clarusway'

# %%
pi = 3.14
r = 5

area = pi * r**2  # alan pire kare  - r**2 bitisik yazilir
print(area)
# Out:
# 78.5

# %%
tues = 25
wed = '11'
thu = '13.5'
fri = 'The weather is '
sat = tues - int(wed)
sun = int(wed) + float(thu)  # thu decimal oldugu icin float yazmaliyiz. int kabul etmez.
mon = fri + str(tues) +  ' on Monday'

print(type(tues), type(wed), type(thu))  # aynı anda 3 variablein typeını yazmak için araya comma, + degil
print()
print(sat)  # first define the value of sat above
print()
print(sun)
print()
print(mon)  # on monday 25 ile ayrı yazılması için ' ve o arasına bir space ekledim
# Out:
# <class 'int'> <class 'str'> <class 'str'>
#
# 14
#
# 24.5
#
# The weather is 25 on Monday

# %%
a = 35.5
b = '24'
c = '6.5'
d = 'Today the weather is '
print(d+ str(a + int(b) + float(c)))
str(a)
d + str(a + int(b) + float(c))
# Out:
# Today the weather is 66.0
# 'Today the weather is 66.0'

# %%
days_in_february = 28
print(str(days_in_february) + ' days in February')  # burada eger str yazmasaydik toplayamazdi error verirdi (str+int olmaz erroru)
# çünkü biri int digeri str. bu nedenle ilk once int'i str yapmak icin basina str yazdik.
# saha sonra satirin nasil devam etmesini istiyorsak onu quotes icinde str olacak sekilde verdik.
# Out:
# 28 days in February

# %%
first_no = '5'
sec_no = '6'
# bu ikisini print deyip parantez ici + yapsak sonuc 56 olur, 2 str yanyana, thus once int yapmali
print(int(first_no) + int(sec_no))  # print(int(firstno + secno)) yazdım olmadi, 56 verdi. yani int parantezi kapsamıyor. 
# tüm degerler icin ayri ayri yazmak gerekiyor.
# acaba bunu float yapip toplayabilir miyim:
print(float(first_no) + float(sec_no))  # evet oldu

# acaba bir int bir float toplayabilir miyim
print(int(first_no) + float(sec_no)) # sonuc verdi. float olarak.
# acaba int ve flolat olarak toplayıp str parantezine alsam str sonucu cikar mi. bir de yazı ekleyip deneyelim
third_no = ' is a good number'
print(str(int(first_no) + int(sec_no)) + third_no)  # evet sonuc verdi. str parantezi iki int'i str yapip diger str ile topladi.
# Out:
# 11
# 11.0
# 11.0
# 11 is a good number

# %%
# 4 işlem (addition, subtraction, multiplication, division, modulus %, exponentiation **, floor division \\ option+ tire)
# modulus % bolum isleminde kalanı, floor division da // tam değeri verir.
a = 15
b = 20
c = 30

print(a + b)
print(c - a + b)
print(a + b * c)
print(b**a)  # ** üssü anlamına geliyor. double exponent means "power of"
print(c/a)
# Out:
# 35
# 35
# 615
# 32768000000000000000
# 2.0

# %%
print(43 // 5)  # bu floor divisionu
print(43 % 5)  # bu da modulusu
# Out:
# 8
# 3

# %%
# We can assign a value to multiple variables. FE:
a = b = c = 5  # each of them becomes five. we can also write strings like that
nation_a = nation_b = nation_c = "Turkish"
print('a, b and c are ' + nation_a)
print()
print(a+b+c)
print()
# sayıları dizi olarak da yazabiliriz
no1, no2, no3 = 30, 40, 60  # We can assign multiple values to multiple variables in sequence using commas as in this example.
no4 = no3/no1 + no2  # sonuc neden 42.0 float cikti: / division isleminde sonuc her zaman float verir
print(no4)
# Out:
# a, b and c are Turkish
#
# 15
#
# 42.0

# %%
# parentheses are used as in normal mathematics operations
print((30/2) * 4)  # division gives float. bölme işleminde sonuc daima ve daima float cikar.
print()
# but in the case below, it gives integer part of division
# floor divisionun bir diğer ismi integer division
print(7 // 2 )  # eger bunu sadece tek / ile yapsak float verir. // ile yapınca mesela 11 // 2 cevap 5 olur.
print(7/2)
print()
print(9%2)  # since 9 is an odd number, the remainder of this division is 1
print(10%3)  # 3 kere 3 9 ve 1 kalır
print()
print(3**2)  # exponentiation - power of
print()
# square root karekök demek
print(64**0.5)  # gives the output as float. cunku burdaki 0.5: üssü 1/2 demek
# Out:
# 60.0
#
# 3
# 3.5
#
# 1
# 1
#
# 9
#
# 8.0

# %%
print('Result of this sum is : ', 12 + 7)
print('If an apple costs 3 Dollar, then 5 apples cost: ', 5*3)  # yazıdan sonra comma olmazsa error verir.
# Out:
# Result of this sum is :  19
# If an apple costs 3 Dollar, then 5 apples cost:  15
