# %%
num1, num2 = 50, 70  # bu bir tuple

# %%
from numpy import pi  # bu ilerinin konusu. numpy libraryden pi'nin degerini import et dedik ve verdi
type(pi)
r = 5  # yarıçapı 5 olan bir dairenin karesi nedir? pirekare oldugu icin piyi import ettik
area = pi * r ** 2 
print(area)
# Out:
# 78.53981633974483

# %% [markdown]
# **Print Function**

# %%
# When using print() we can write more than one expression in parentheses separated by commas
text = 'today the weather is'
number = 19
print(text, number)
# metinde 19 oncesi space virgul oldugu icin virgul sonrasına otomatik koyar str.
# eger virgul sonrası space bırakmasak bile PEP 8 metinde koyar onu
# The print() command automatically switches to the next line. This is due to the keyword argument end = "\n"
print("Today, I went to Bochum due to an urgent call from ", 201686868, "early in the morning")
# mesela bu ornekte from sonrası ben boşluk vermisim yanlis, bir de virgul otomatik boslugu olunca ciktida 2 space
# Out:
# today the weather is 19
# Today, I went to Bochum due to an urgent call from  201686868 early in the morning

# %%
text1 = "I bought"
text2 = "kg. of apple this morning."
amount = 6
text3 = text1 + " " + str(amount) + " " + text2
print(text1, amount, text2)
print(text3)
print("I bought", 6, "kg. of apple this morning.")
print("I bought", "6", "kg. of apple this morning.")
# Out:
# I bought 6 kg. of apple this morning.
# I bought 6 kg. of apple this morning.
# I bought 6 kg. of apple this morning.
# I bought 6 kg. of apple this morning.

# %% [markdown]
# **floor division and modulus**

# %%
print(11 % 2)  # modulus almak sayinin cift mi tek mi oldugunu verir
print ((4 * 5) / 2)
# Out:
# 1
# 10.0

# %%
print(3 ** 2)  # square of 3
a, b = 2, 8
print((a * b) ** 0.5)  # square root. bir işlemde bölme varsa sonuc daima float
# burada 16 üzeri bir bölü 2 var. o da bolme ondan dloat
# Out:
# 9
# 4.0

# %% [markdown]
# **Escape Sequences**
#
# - \' (ters slash ve ')  This represents a single quote
# - \n   This represents a new line
# - \r   This represents a carriage return (satır başına getirme)
# - \t   This represents a tab - four spaces
# - \b   This represents a backspace
# - \f   This represents a formfeed (sayfa ilerletme, sayfa başı tuşu)
# - \ooo This represents an octal value (sekizli-oktal)
# - \xhh This represents a hex value (hex v: onaltılık değer)
# - \\   This represents a backslash
# - \uxxxx  This represents 16 bits hex value
# - \uxxxxxxxx  This represents 32 bits hex value

# %%
# \n represents new line.
# If we didn't use end=' ', we would normally get 4 lines of output.
# Ama string quotes end'den once bitmeli. ilki yanlis ikincisi dogru
print('Tomorrow is Friday, end=' '')
print("we'll meet the parents in the committee, end=' '")
print('for the, end=' '')
print('first time.')

print()
# in this example we have combined all expressions with space in a single line using the 👉🏻end= 
print('Tomorrow is Friday', end=' ')  # mesela boyle dogru yapinca end=' ' argumentinin rengi degisti.
print("and we'll meet the parents in the committee", end=' ')
print('for the', end=' ')
print('first time.')
# Out:
# Tomorrow is Friday, end=
# we'll meet the parents in the committee, end=' '
# for the, end=
# first time.
#
# Tomorrow is Friday and we'll meet the parents in the committee for the first time.

# %%
# print (x, y) burada sep parametresi calisiyor sep=' ' ve bu koyuyor virgülü
# end parametresi de end='\n' alt satıra geciriyor (n yerine baska sey de yazılabilir)
print("ali", "veli")
print("deli")  # alt satıra geçme nedeni built-in end='\n'
# Out:
# ali veli
# deli

# %%
print('smoking', 'is', 'slowly', 'killing me', sep=' + ')
print('')
print('If you', 'want to be', "successful,", "then you have to practice more.", sep=' + ')  # Sep ici + ise bu, bossa alttaki.
print('If you', 'want to be', "successful,", "then you have to practice more.", sep='  ')
# Out:
# smoking + is + slowly + killing me
#
# If you + want to be + successful, + then you have to practice more.
# If you  want to be  successful,  then you have to practice more.

# %%
print('I will say', end=' ')  # bu örnekte end= yazdım ' ' koymadım sonrasında ve error verdi.
print('my mother', end=' ')
print('hi.')
# Out:
# I will say my mother hi.

# %%
print("ali", "veli", end="*******")  # burada da **** koyarak new line yerine *** ile bitirttik
print("veli")
# Out:
# ali veli*******veli

# %%
# Sep parameteri default olarak sep=' ' olarak tanımlanmıştır ve expressionlar arası
# space bırakır. bir whitespace. Ama bunu degistirerek expressions arasını değiştirebiliriz.
print("ali", "veli", "deli", sep=" ")  # bu normal default olan
print("ali", "veli", "deli", sep="&")
print("Clarusway", "Clarusway", "Clarusway", end="\n" "a")
# Out:
# ali veli deli
# ali&veli&deli
# Clarusway Clarusway Clarusway
# a

# %%
# bu parametreleri list'in ortasında da kullanabiliriz. ama end='\n' sonrası comma(,) olmamalı, yoksa error verir.
print("ali", "veli", end='\n' "deli")
# Out:
# ali veli
# deli

# %%
print(False, "veli", 3.14, 50, sep = "**")  # bu örnekte araları ** ile degistirdik
print(False, "veli", 3.14, 50, sep = "")  # direkt yanyana "" yaparsak aradaki spacei kaldırmış oluruz
# Out:
# False**veli**3.14**50
# Falseveli3.1450

# %%
# aynı şekilde end parametresinde de default olan new line: end= '\n' Ama bunu da degistirebiliriz
print("ali", "veli ", end='çocuklarıdır ')
print ("ahmet ile ayşe'", end='nin' ".")  # hoca örnekte en son noktayı alta print(".") yapmisti
# ben burada end='nin' sonrasına yazdım direkt (virgülsüz) yine oldu.
# yani end'e ne value atarsan onunla bitirir line'ı ve ona gore asagi gecer
# Out:
# ali veli çocuklarıdır ahmet ile ayşe'nin.

# %%
print("Ali degil benim adım", end=' belki bir işçi sadece')
print("bugün günlerden", end='gs') #bu ikisi aynı satırda print edecek, çünkü end='\n' komutunu iptal etmiş olduk
# Out:
# Ali degil benim adım belki bir işçi sadecebugün günlerdengs

# %%
# sep='\n' new line
# sep="\t" aralarda tab boslugu birakir
print("one", "two", "three", sep="\t") # separated by tab marks
print('ali', 'veli', 'mehmet', sep="\t")

# sep="\n" leaves new line
print('ali', 'veli', 'mehmet', sep="\n")  # her birini ayrı satırlarda yazar 
print()
# Out:
# one	two	three
# ali	veli	mehmet
# ali
# veli
# mehmet

# %%
# \b means backspace. It moves the cursor one character to the left. 
print('we', '\bare', '\bunited') # remember, normally print() function separates expressions by spaces
print('Today', '\bIs', '\bThe', '\bFirst', '\bDay.')
print('Clarusway', 'Clarus', 'Way', end='\b' )
# Out:
# united
# Day.
# Clarusway Clarus Way

# %%
# Normally when we use 👉🏻' inside the 👉🏻' ', Python gives error.
# But here, in the example below, 👉🏻\ allows single-quote 👉🏻' to be ignored.
print('it\'s ok with Phyton.' )
# IMP: Phyton ignores any character which comes immediately after \
# normalde bu örnekte quotes single, it's deki apostrof eror verirdi ama önüne \ koyarak engelledik.
# Out:
# it's ok with Phyton.

# %%
# ama \ bunu sadece özel anlamı olan karakterlerle yapar. örn:
print('Ahmet Bey\in ceketi')
# burada i'nin özel bir anlamı yok. dolayısyla yukarıdaki gibi bir hatayı çözme durumu
# olmadigi icin burada \ işaretinin escape sequence olma özelliği kalmadı. onu da direkt
# print etti. eger yanına n, t, b, ? vb gelirse esc seq olur.
# Out:
# Ahmet Bey\in ceketi

# %%
print('Ayla\nın çantası')  # mesela burada hemen sonrasında n olduğu için \n olarak algıladı ve new line yaptı
# ama önüne bir \ daha koyarak bunu etkisini ortadan kaldırabiliriz.
print('Ayla\\nın çantası')
# Out:
# Ayla
# ın çantası
# Ayla\nın çantası

# %%
print('C:\\north pole\noise_penguins.txt')
print('----------')
print('first', 'second', 'third', sep= '\t')
# Out:
# C:\north pole
# oise_penguins.txt
# ----------
# first	second	third

# %%
print('we are', '\boosting', 'our', '\brotherhood.')
print('it\'s essential to learn Python\'s libraries')
# Out:
# rotherhood.
# it's essential to learn Python's libraries

# %% [markdown]
# **Arithmetic Operations**

# %%
# Any mathematics operator can be used before the = character to make an in-place operation
# -= decrements the variable in place, (decrement: azaltma, eksiltme - decrease)
# += increment the variable in place, (increment: artırma, toplama - increase)
# *= multiply the variable in place,
# /= divide the variable in place,
# //= ﬂoor divide the variable in place,
# %= returns the modulus of the variable in place,
# **= raise to power in place.

x = 5
print('value of x     : ', x)
x += 2
print('2 more of x    : ', x, "\n")  # using string expression '\n', we produce an extra empty line
x -= 3
print('3 minus x      : ', x, "\n") 
y = 10
y *= 2
print('2 times y      : ', y, "\n")  # yukarıdakilerin hepsiyle yapılabilir.
# Out:
# value of x     :  5
# 2 more of x    :  7
#
# 3 minus x      :  4
#
# 2 times y      :  20

# %%
Ali = 15
Ali += 2
print(Ali)
Ali -= 5
print(Ali)
Ali=15
Ali -= 6
print(Ali **0.5)
# Out:
# 17
# 12
# 3.0

# %% [markdown]
# **Boolean Operations**

# %%
# Python has three built-in boolean operators: 
# and, or and not. 
# Except not, all are binary operators, which means two arguments are required.
# And operator : The and operator evaluates all expressions and returns the last expression if all expressions are evaluated True. 
# Otherwise, it returns the ﬁrst value that evaluated False.
# Or operator : The or operator evaluates the expressions left to right and 
# returns the ﬁrst value that evaluated True or the last value (if none is True).
# not operator :it evaluates the expression that follows it as the opposite of the truth. eg: not True means False

# %%
# And True gördükçe True verir, en sona kadar bakar. False gördüğü anda F verir
print(True and True and True)
# Out:
# True

# %%
# printsiz de çalıştırabiliriz bunu
True and True and True
# Out:
# True

# %%
# Rakamların boolean değeri True'dur. 0 (sifir) ve None ise F
bool(1)
bool(2)
bool(486)
# Out:
# True

# %%
# T ve F yerine atanan değerler truty veya falsy olur
1 and 2 and 3 and 5000  # burada en sona kadar bakacak ve hep T gorunce en son truty'yi verecek
# Out:
# 5000

# %%
bool(0)  # 0 ve None F
bool(None)
# Out:
# False

# %%
bool("0")  # bu dolu bir string oldugu icin T olur
# Out:
# True

# %%
bool(" ")  # bu da dolu bir str. space de bir character
# Out:
# True

# %%
bool("")  # ama burada bir karakter yok. "" F olur
# Out:
# False

# %%
bool() # boş parantez F verir. aynı şekilde (()) ya da [] bu da F
# Out:
# False

# %% [markdown]
# and Operatoru

# %%
# and ilk F hangisi ise onu return eder. Orn. burada ilk F 0, onu returns eder
# eger - yerine False olsaydi ilk deger onu return ederdi. F'a karşı cok hassas yani, hep F arıyor. 
# T gördükçe hep bir sonrakine geçiyor ve devam ediyor aramaya
0 and None and 1  # mesela burada ilk falsy'yi verir direkt
# Out:
# 0

# %%
False and True and True  # ilk Fu verir
# Out:
# False

# %%
print(2 and "hello world")  # sona kadar bakar and, bulamyınca son Tyi verir
print([] and " be happy")  # and ilk Fu verir
print (None and ())  # ilk Fi verir.
# Out:
# hello world
# []
# None

# %%
ali = True
veli = False
mehmet = False
ali and veli and mehmet  # burada verdigi F ilk gordugu F, yani veli
# Out:
# False

# %% [markdown]
# or operatoru

# %%
# and'in tam tersine bu true'ya takıntılıdır. 
# orn. iki F varsa sırayla T arar. bir f ise 2ye, o da f ise 3'e, 
# oyle oyle t aramak icin en sona kadar gider. en sonda f ise f verir
# ama t bulursa t verir. ya da truty veya falsy degerleri neyse onları verir
True or True or True  # ilk T'yi gordugu gibi T der
# Out:
# True

# %%
1 or "ali" or True  # 1 vermesinin sebebi truty olan 1'in True olması. Rakamlar T
# Out:
# 1

# %%
False or False or False  # eger hepsi F ise sonuncu Fi verir
# Out:
# False

# %%
# None, 0, "", (), [] bunlar her zaman F dur. (dikkat None uppercase)
# Falsy values in python: None, Zero (0, 0.0, 0j), empty seq. () and collections ('', [], {})
# geriye kalan herşey true 
0 or None or "" or ()  # en sona kadar T aradı bulamayınca sonuncu F'u verdi.
# Out:
# ()

# %%
print(2 or 'hello world')
print([] or "be happy")
print(None or ())
print({} or 0)
print({0} or False)
# Out:
# 2
# be happy
# ()
# 0
# {0}

# %% [markdown]
# Not operatoru

# %%
# not boolean ifadeleri hep tersine çevirir. T ise F, F ise T yapar.
not 9  # normalde 9 T ama not deyince F verdi
# Out:
# False

# %%
not 0  # normalde 0 F ama not T verdirdi. "" ve (), [] icin de aynen T yapar not
# Out:
# True

# %%
print(not "ali")  # dolu strler T olur ama not F return etti
# printli veya printsiz (not "ali") aynı ciktiyi verir
# Out:
# False

# %%
# Order of Prioirty of boolean operators: not, and, or sırasıyla.
# aynı listede yanyanalarsa ilk once notun gereği sonra and sonra or'un gereği yapılır
bool_var= False and not True  # F and F oldu bu ornekte
print(bool_var) 
type(bool_var)
# Out:
# False
# bool

# %%
True and False or not False or False 
# ilk once nota bakariz not T yapti ücüncüyü. yani artik T and F or T or F
# daha sonra priority and'de. ilk ikisinden F cikti. F or T or F kaldı
# ilk ikisi f or t T cikar. kalan ikisi de T or F T cikar
# Out:
# True

# %% [markdown]
# SUMMARY

# %%
print('Value1', 'Logic', 'Value2', 'Returns', sep = '\t')
print("True", "and", "True", "True", sep='\t')
print("True", "and", "False", "False", sep='\t')
print("False", "and", "False", "False", sep='\t')
print("False", "and", "True", "False", sep='\t')
print("True", "or", "True", "True", sep='\t')
print("True", "or", "False", "True", sep='\t')
print("False", "or", "False", "False", sep='\t')
print("False", "or", "True", "True", sep='\t')
# Out:
# Value1	Logic	Value2	Returns
# True	and	True	True
# True	and	False	False
# False	and	False	False
# False	and	True	False
# True	or	True	True
# True	or	False	True
# False	or	False	False
# False	or	True	True
