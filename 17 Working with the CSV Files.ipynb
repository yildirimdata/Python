# %% [markdown]
# # Working with the CSV Files
#
# Another widely used file type in all programming languages is CSV files. CSV stands for Comma Separated Values. Due to its simple structure and easy creation, data with various contents are usually stored in this format.
#
# Actually, it's a plain text like .txt files. Normally, CSV files use a comma to separate each specific data value. When you save the plain text file that you create by using a simple text editor (such as Notepad in Windows OS) as a .csv extension, then you create a CSV file.
#
# A CSV file is basically a table made up of rows and columns. The structure of a simple CSV file is as follows :
#
# column 1,column 2,column 3
#
# first row 1,first row 2,first row 3
#
# second row 1,second row 2,second row 3
#
# third row 1,third row 2,third row 3
#
# ......

# %%
# task: let's create a csv file consisting of fruits. 3 columns and 5 rows
# I write these to a txt file and then rename its extension as csv
# It transformed it automatically to a table woth rows and columns.

# %% [markdown]
# **How to read csv files**
#
# There are several ways to read CSV files in Python.
#
# 1. We can use the ordinary way of reading using open() function and .read() method.
#
# 2. We can use csv Module.
#
# 3. We can use the Pandas library for which created data analysis purposes. It is highly recommended if you have a lot of data to analyze. (In next module)

# %%
# 1. Ordinary Reading Method of CSV Files
with open("fruits.csv", "r", encoding = "utf-8") as file:
    print(file.read())
    
# with a file including huge data, this reading method is useless.
# Out:
# no,fruit,amount
# 1,Banana,4 lb
# 2,Orange,5 lb
# 3,Apple,2 lb
# 4,Strawberry,6 lb
# 5,Cherry,3 lb

# %%
with open("titanic.csv", "r", encoding = "utf-8") as file:
    # print(file.read())
# Out:
#   Input In [19]
#     # print(file.read())
#                         ^
# IndentationError: expected an indented block

# %% [markdown]
# # Reading the CSV Files with 'csv' Module
#
# **read_csv() method**
#
# **Read a comma-separated values (csv) file into DataFrame.**
#
# Since the content of the CSV files is displayed in a more readable and regular format with this method, this method is more preferred than the previous one.
#
# First of all, of course, we should **load csv module*. Secondly, we will use *csv.reader() function in a for loop to read the CSV file**.

# %%
# pandas ile acalim
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Sex.value_counts(dropna = False)  
# dosyadan sadece Sex sütununu aldım ve 
# kaç çeşit cinsiyet varsa onların sayılarını elde ettim.
# dosyamda 577 erkek, 314 kadın varmış.
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# bayanlar değişkenimi oluşturuyorum.

bayanlar = df[df["Sex"] == "female"]  # df tablosunun sadece Sex sütununda 
                                    # "female" yazan satırlarını bana getir.

bayanlar
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
bayanlar.to_csv("titanic_bayanlar.csv", index = False)

# artık titanic_bayanlar.csv isminde yeni bir csv dosyam var.

# %%
# yeni csv dosyamızı okutturalım:

df_bayan = pd.read_csv("titanic_bayanlar.csv")
df_bayan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              3         1       3
# 2              4         1       1
# 3              9         1       3
# 4             10         1       2
# ..           ...       ...     ...
# 309          881         1       2
# 310          883         0       3
# 311          886         0       3
# 312          888         1       1
# 313          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1                               Heikkinen, Miss. Laina  female  26.0      0
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 3    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 4                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# vefat edenlerin listesini alalım:

vefat = df[df["Survived"] == 0]
vefat
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# vefat edenlerin listesinden yeni bir csv dosyası oluşturalım:4

vefat.to_csv("titanic_vefat.csv", index = False)

# %%
# pandas derslerinde detaylı gösterilecektir.

df.groupby("Sex")["Survived"].mean() # cinsiyet cinsiyet kurtulanların ortalamalarını aldım
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df[df["Sex"] == "female"]  # Tablonun cinsiyet sütununda "female" yazan satırları çektim..
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Çektiğim bu satırların Survived sütunundaki değerlerine bakmak için value_counts metodunu kullandım.
# 0 kurtulamayanlar, 1 kurtulanlar.

df[df["Sex"] == "female"]["Survived"].value_counts()
# Out:
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
# şimdi sınıf ("Pclass" sütunu) bazında bir gruplama yapalım.
# ve onların kurtulma durumunu inceleyelim:

df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
# sınıfların kurtulma durumlarının "histogram" grafiğine bakalım:

df.hist("Pclass", "Survived")
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %%
# cinsiyetlerin kurtulma durumlarının grafiğine bakalım:
df.hist("Sex", "Survived")
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %% [markdown]
# Soldaki grafikte; Suvived sütunu 0 olan yani vefat eden erkeklerin kadınlara göre çok daha fazla olduğunu görüyoruz.
#
# Sağdaki grafikte; Survived sütunu 1 olan yani kurtulanların grafiğini görüyoruz. Kurtulan kadınlar erkeklerden çok daha fazla.
#
# (basit manada grafikler çizdirmiş olduk.)

# %%
# bu da read_csv metodu ile okuma csv file'ı
df = pd.read_csv("titanic.csv")

df

# %%
import csv  # loads csv module

with open("fruits.csv", 'r', newline = '', encoding = 'utf-8') as file:
    csv_rows = csv.reader(file)  # reader() function takes each row (lines) into a list
                                 
    for row in csv_rows: 
        print(row)
# Out:
# ['no', 'fruit', 'amount']
# ['1', 'Banana', '4 lb']
# ['2', 'Orange', '5 lb']
# ['3', 'Apple', '2 lb']
# ['4', 'Strawberry', '6 lb']
# ['5', 'Cherry', '3 lb']

# %% [markdown]
#  the rows are displayed in the list type. Each element of the rows is located as separate strings in the list. There are three strings in each list.

# %% [markdown]
# **Tips:**
#
# If newline='' is not specified, newlines embedded inside quoted fields will not be interpreted correctly, and on platforms that use \r\n linendings on write an extra \r will be added.
#
# It is the best practice and always safe to specify newline='', since the csv module does its own newline handling.

# %% [markdown]
# The default value of the delimiter parameter is ",". Thus, we can display each comma-separated element as separate strings. At this time let's use the delimiter="," parameter and see the same result as the previous one.

# %%
import csv

with open("fruits.csv", 'r', newline = '', encoding = 'utf-8') as file:
    csv_rows = csv.reader(file, delimiter= ",")  # gives the same output as the previous one
                                 
    for row in csv_rows: 
        print(row)
# Out:
# ['no', 'fruit', 'amount']
# ['1', 'Banana', '4 lb']
# ['2', 'Orange', '5 lb']
# ['3', 'Apple', '2 lb']
# ['4', 'Strawberry', '6 lb']
# ['5', 'Cherry', '3 lb']

# %% [markdown]
# We can also display each row in the list as a single string. If we determine a character that is not included in the CSV file and allocate this character as the value of delimiter, we can print all lines of the CSV file as lists as a single string element. Consider this one :

# %%
import csv 

with open("fruits.csv", 'r', newline = '', encoding = 'utf-8') as file:
    csv_rows = csv.reader(file, delimiter = ':')  # we specified a char ":" that is not used
                                                  # in the csv file as a value of delimiter
    for row in csv_rows: 
        print(row)
# Out:
# ['no,fruit,amount']
# ['1,Banana,4 lb']
# ['2,Orange,5 lb']
# ['3,Apple,2 lb']
# ['4,Strawberry,6 lb']
# ['5,Cherry,3 lb']

# %% [markdown]
# # Online tutorials for JSON Files reading and writing
#
#
# Javascript Object Notation
#
# https://www.youtube.com/watch?v=KnAyziNnuI0
#
# https://www.youtube.com/watch?v=9N6a-VLBa2I&t=18s
#
# for demo:
#
# https://www.youtube.com/watch?v=1ty7D--lbXU
